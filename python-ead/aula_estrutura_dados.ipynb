# %% [markdown]
# A partir desse notebook, vamos começar a estudar sobre como utilizar o python para realizar operações que possam nos ajudar no dia a dia.
#
# Com esse notebook, iremos estudar os seguintes conceitos:
#
# - leitura de estrutura de dados.
# - realizar ações para nos ajudar a estrutura e entender os dados.
# - aplicação de funções de agregações
# - visualizar o resultados.

# %% [markdown]
# Iremos iniciar nossos estudos pela biblioteca do pandas.
#
# Em diversas oportunidades como engenheiro ou cientista de dados, temos que lidar com situações de ler tipos de arquivos
# que pode ser:
#     - csv
#     - excel
#     - html
#     - txt
#     - e etct.
#
# A biblioteca do pandas, é otima para realizar esse tipo de trabalho. Ela fornece uma serie de métodos/funções que irão nos ajudar a realizar a leitura dessas estruturas.

# %%
#importando a biblioteca do pandas (https://pandas.pydata.org/)
import pandas as pd

# %% [markdown]
# Como comentado, um dos beneficios de se trabalhar com o pandas é a facilidade que se tem em trabalhar com arquivo. Uma vez que esses arquivos são lidos, basicamente eles são convertido em dataframe ou serie.
#
# Um dataframe, é uma estrutura composta por linhas e colunas. Na Imagem abaixo podemos ver como ela fica:
#
# </br>
#
# <img src="imagem/dataframe.jpg" width=160 height=80 align='left' /> </br>
#
# </br></br>
#
# Uma outra estrutura, é quando existe apenas uma coluna no arquivo. Nesse caso é chamado de serie. Veja imagem abaixo:
#
# <img src="imagem/serie.png" width=200 height=90 align='left' />

# %%
#metodo responsavel por realizar a leitura do arquivo
titanic_df = pd.read_csv('dataset/titanic.csv')

# %%
#com o metodo head, podemos ler a quantidade de linhas que desejamos.
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
#já com o shape, podemos avaliar a estrutura do arquivo
titanic_df.shape
# Out:
# (891, 12)

# %% [markdown]
# <b>Exercicio.</b>
# 1. com o shape, podemos avaliar a estrutura do arquivo. Repare na resposta que ele parece um array. Imagine que gostariamos apenas de retornar a quantidade de linhas, como podemos fazer?
#
# 2. com o metodo head, retornamos a quantiade de linhas do arquivo de cima para baixo, se queremos de baixo para cima, executamos o metodo tail. Execute ele.

# %%
titanic_df.shape[0]
# Out:
# 891

# %%
titanic_df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# vamos ver um metodo bastante util. o describe, com ele podemos retornar algumas informações de estatistica do arquivo.
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
round((titanic_df.isnull().sum() * 100) / titanic_df.shape[0],2)
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %%
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# <b>Exercicio.</b>
# 3. tire a porcentagem de dados nulos

# %% [markdown]
# <b>loc:</b>
#
# Gosto bastante do loc, com ele podemos realizar alguns filtros dentro do nosso data frame. Esses filtros pondem ser tanto feitos pelas colunas ou pelos indexes.

# %%
titanic_df.loc[titanic_df.Survived >= 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex  idade  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                               Heikkinen, Miss. Laina  female   26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female   14.0      1
# ...

# %%
titanic_df.loc[:70].head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
novo_titanic_df = titanic_df.loc[(titanic_df.Sex == 'male') & (titanic_df.Age > 35)]

# %% [markdown]
# <b>Exercicio</b>
# 4. Nesta etapa quero que vc crie um novo dataframe, uma variavel, ela só poderá ter pessoas do sexo masculino e que tenham mais que 35 anos de idade.

# %%
#renomear o nome das colunas.
titanic_df = titanic_df.rename(columns={"Age": "idade"})

# %%
#Depois de executar o metodo de rename, e agora executar o metodo head, vimos que a coluna Age não mudou o nome, porque?
titanic_df.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex  idade  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                             Heikkinen, Miss. Laina  female   26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %% [markdown]
# <b>Exercicio</b>
# 5. Renomei todas as colunas, conforme seu entendimento

# %% [markdown]
# Muita das vezes vamos querer deletar uma coluna do nosso dataset, podemos fazer isso usando o metodo <b>drop</b>

# %%
#drop
titanic_df.drop('Name', axis=1)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# <b>Exercicio</b>
#
# 6. Crie um novo dataframe, porém somente com as colunas: Survived, Pclass, Sex, Age, Ticket, Embarked

# %%
titanic_df_novo_aula = titanic_df[['Survived', 'Pclass', 'Sex', 'idade', 'Ticket', 'Embarked']]

# %%
titanic_df_novo_aula
# Out:
#      Survived  Pclass     Sex  idade            Ticket Embarked
# 0           0       3    male   22.0         A/5 21171        S
# 1           1       1  female   38.0          PC 17599        C
# 2           1       3  female   26.0  STON/O2. 3101282        S
# 3           1       1  female   35.0            113803        S
# 4           0       3    male   35.0            373450        S
# ..        ...     ...     ...    ...               ...      ...
# 886         0       2    male   27.0            211536        S
# 887         1       1  female   19.0            112053        S
# 888         0       3  female    NaN        W./C. 6607        S
# 889         1       1    male   26.0            111369        C
# 890         0       3    male   32.0            370376        Q
#
# [891 rows x 6 columns]

# %% [markdown]
# Com o metodo <b>unique</b>, podemos retornar apenas os dados unicos de uma determinada Serie.

# %%
titanic_df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# Com o <b>value_counts</b>, podemos retornar q quantide de cada valor dentro da Serie.

# %%
titanic_df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
round(titanic_df['Pclass'].value_counts(normalize=True),2)
# Out:
# 3    0.55
# 1    0.24
# 2    0.21
# Name: Pclass, dtype: float64

# %%
titanic_df['X'] = 1

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  idade  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                               Heikkinen, Miss. Laina  female   26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
# 4                             Allen, Mr. William Henry    male   35.0      0
# ...

# %% [markdown]
# Um metodo que será bastante utilizado será o metodo <b>groupby</b>, podemos até comparar ele com o group by do sql. Porém construir com o pandas é bem simples.

# %%
titanic_df[['Pclass', 'X']].groupby("Pclass").sum()
# Out:
#           X
# Pclass
# 1       216
# 2       184
# 3       491

# %% [markdown]
# <b>Exercicio</b>
#
# 7. Faça um groupby, e retorne somente as idades. Quero que forme faixas.

# %%
titanic_df[['idade', 'Contador']].groupby("idade").sum()
# Out:
#        Contador
# idade
# 0.42          1
# 0.67          1
# 0.75          2
# 0.83          2
# 0.92          1
# ...         ...
# 70.00         2
# 70.50         1
# 71.00         2
# 74.00         1
# 80.00         1
#
# [88 rows x 1 columns]
